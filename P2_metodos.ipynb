# %% [markdown]
# # **O impacto do teste rápido da COVID 19 em uma comunidade urbana com base em um modelo SIR modificado 📊**

# %% [markdown]
# Alunos 📚:
#
# Alice Buarque Cadete (abc3@cin.ufpe.br)
#
# Beatriz Galhardo Carneiro Leão (bgcl@cin.ufpe.br)
#
# Danilo Lima de Carvalho (dlc3@cin.ufpe.br)
#
# Luisa Fonseca Leiria de Andrade (lfla@cin.ufpe.br)

# %% [markdown]
# # Resumo 📘

# %% [markdown]
# A pandemia do COVID, que se espalhou pelo mundo desde 2019, representou uma grave ameaça à vida humana. Existem diversas maneiras de controlar a dispersão da pandemia, tais como: promover a vacinação, uso de máscaras, limitar o número de pessoas em espaços públicos, entre outros. Nesse projeto, vamos utilizar o modelo compartimental SEIQR para analisar a propagação da COVID-19 sob a promoção de testes rápidos. Utilizando um requisito de número mínimo estimado para o uso de testes rápidos, foi possível desenvolver sugestões razoáveis para o controle da pandemia.
#
# Para desenvolver tal analise utilizamos dados como a sensibilidade de diferentes tipos de testes rápidos que se encontra em torno de 85%. Também foi constatado que a porcentagem mínima da população que realiza o teste rápido por dia se encontra em cerca de 30%, isso porque, diferente de outros tipos de testagem, como o método PCR, a testagem rápida é mais simples e fácil de realizar.
#
# Utilizando tais dados, foi desenvolvido um modelo modificado do famoso modelo SIR, o SEIQR, nessa modificação foram adicionadas duas classes, referentes à exposição e à quarentena, importantes fatores que contribuem para a transmissão e propagação da COVID 19.

# %% [markdown]
# # Introdução 📓

# %% [markdown]
# A partir de dezembro de 2019, o COVID-19 causou um surto de pneumonia viral em todo o mundo e teve um efeito drástico na vida das pessoas desde então. Mesmo com o desenvolvimento de tratamentos e procedimentos de teste, a pandemia ainda representou um risco enorme para a saúde pública.
#
# O teste PCR (Polymerase Chain Reaction test) é amplamente confiado para identificar com precisão infecções por SARS-CoV-2. Apesar  da sua confiabilidade, os resultados demoram um tempo entre 1 e 3 dias para serem recebidos. Por isso, testes rápidos, que detectam anticorpos, foram desenvolvidos para promover uma forma mais rápida e barata de identificar casos de COVID, já que o teste pode ser feito em casa e com o resultado entregue em cerca de 15 minutos.
#
# O propósito desse estudo é discutir como a popularização de testes rápidos podem influenciar a dinâmica da pandemia. Para responder perguntas como qual a precisão necessária e qual a fração da população precisa ser testada, uma simulação numérica foi construída para determinar o potencial, o fator ‘k’ de testes rápidos na pandemia do COVID.
#
# Para que a analise seja possivel serão utilizados dados como:
#
# - Taxa de nascimento por unidade de tempo
# - Taxa de mortalidade por pessoa por unidade de tempo
# - Taxa de fatalidade da covid 19
# - Probabilidade de transmissão da COVID 19 por unidade de tempo
# - Taxa de progressão da exposição da infecção por unidade de tempo
# - Taxa de recuperação de individuos infectados
# - Sensibilidade ao teste rápido
# - Porcentagem da população que realizou o teste rápido
#
# Tais dados foram extraidos do artigo, utilizado como base para o projeto, visto que os valores apresentados se aproximam bastante da realidade brasileira.
# Assim como no Brasil, o Canadá, país estudado no artigo sofreu grande impacto com a pandemia da COVID 19, tendo altas taxas de infecção e mortes.
#
# No artigo também foi apresentado que a taxa de sensibilidade dos testes rápidos estudados possuem uma sensibilidade de 85% em média, tal valor também se aplica aos valores dos testes brasileiros, isso porque esse é o valor mínimo permitido pela ANVISA para testes rápidos disponiveis no país.
#
# A partir de tais dados um modelo comportamental SEIQR foi desenvolvido a partir da modificação do modelo SIR.
#
# No modelo SEIQR foi analisada a interação entre os individuos e os parâmetros descritos acima visando entender a propagação da COVID 19 e a sua relação com o número de testes rápidos realizados pela população, assim como a sua eficiência.

# %% [markdown]
# # Objetivos 🎯

# %% [markdown]
# Além da simulação numérica do impacto dos testes rápidos na pandemia de COVID-19, o projeto visa também uma análise detalhada dos resultados obtidos. Isto envolve interpretar as informações produzidas pelo modelo de comportamento modificado, levando em consideração diferentes cenários e parâmetros.
#
# Nesta análise, a apresentação gráfica dos resultados desempenha um papel decisivo, o que permite uma visualização clara do efeito dos testes rápidos na propagação da doença. Esta abordagem visual fornece informações valiosas aos decisores políticos e aos profissionais de saúde, facilitando decisões informadas sobre a utilização e implementação de testes rápidos.
#
# Além disso, o objetivo do projeto não é apenas determinar a sensibilidade mínima dos testes rápidos, mas também avaliar a eficácia destes testes em diferentes contextos e condições. Isto inclui analisar como fatores como as taxas de prevalência de doenças, as taxas de testagem da população e a capacidade de resposta do sistema de saúde podem afectar os resultados. Considerando estes aspectos, o projeto visa fornecer orientações mais precisas e adaptativas para o uso estratégico de testes rápidos para gerir eficazmente a pandemia.
#
# Para que tais objetivos sejam efetivos utilizaremos um fator k = (sensibilidade ao teste rápido * porcentagem de pessoas que realizaram o teste) para demonstrar o impacto positivo que os testes rápidos podem provocar em uma pandemia, em relação ao número de pessoas em quarentena, infectadas, suscetíveis, expostas e removidas.
#
# Finalmente, o projeto visa promover o desenvolvimento de políticas de saúde pública mais eficazes na gestão de doenças infecciosas. Ao criar uma base sólida de evidências e análises e recomendações práticas para a implementação de testes rápidos, o projeto visa capacitar os decisores políticos para tomarem decisões informadas e proativas para proteger a saúde pública. Esta abordagem baseada em dados é necessária para enfrentar os desafios complexos da pandemia da COVID-19 e garantir uma resposta eficaz e coordenada para proteger as comunidades em todo o mundo.

# %% [markdown]
# # Mapa mental 🗺

# %% [markdown]
# ![MapaMental](https://coggle-downloads-production.s3.eu-west-1.amazonaws.com/b8eab7b41e72715e1d3c09bb94ce5fffb5de2ad3d64d168e11b53c17759d1002/O_impacto_do_aquecimento_global_na_populao_de_lobos_e_alces_em_Isle_Royale_National_Park.png?AWSAccessKeyId=ASIA4YTCGXFHGBIFUDF6&Expires=1691478279&Signature=sqRJDGD0AlI%2F6xP%2BOnUbjtHWFDQ%3D&X-Amzn-Trace-Id=Root%3D1-64d194a5-d332f51662a332cf29fd8ba8%3BParent%3D06123a3700bb8617%3BSampled%3D0%3BLineage%3D51963df5%3A0&x-amz-security-token=IQoJb3JpZ2luX2VjENn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCWV1LXdlc3QtMSJHMEUCIA2d4daBo7sNmXdSx%2FI1GQMWRu7cDt%2FwXhGYUWAuACMCAiEA7UL4QI2%2FAbHLZuXtlUJsXo5txfJhdmjR9%2FkzV9mJAq8qiwMIgv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw4Nzc0NTMwMzE3NTgiDLRewt%2FS2aAE2e4KryrfAv6J8j9c3xH4fu1oM2wwe%2BX%2FYZHHJHRO%2BMIng1266ph%2Fh9C2IQ%2BCr9Ch5%2FlwHqfV9qT8aoHS4VIOZUBFSoscsoqpOx%2Bks9C1k4oeqYzIoarmDQTiw9yuTKU71p4rhds8bRjlgshxmoEENLwHyE2amQVBdDP6YDYN2PpKR9q3hcSdPPNUd1hJS7CBOpjsumWW6YbO6sU7ugqqziaupQAAZiCLmQtnrNgFmp6J%2FHIu6XTnXiMX8FeDHI6lyQ6eX9C%2BU305KPNv1Tt4akF%2FUu9gpHmoI1sM1tDeI6y1BZS60go4DL60lEPpeKl6XF%2BP5F8AOKula5eVnR5NEf87WjmrKosxFzUK1ca7GzcxR1fR2xehq1wFNUBxEGWcRlp02ccAnpAQPrbIN6yEyJvLngUeOqbRGiKEPHh4ehhW0J6DkEybESREx6As7SCy2kF2RsR56Cob1B924p8wB9P46aRPgDDdpsamBjqeAQph7cuqv8AJYyRzBwEBvg5uqnitdliu4ik4LLf5f36QSxebOdkKzds4%2FqJrj4qHTkpeQ%2BTQzZ%2FsKpIVrbVPqGX8%2FqXXq6r%2BKbIcaQIOymy5N%2BGErm29gdiUPz%2BSaNGdVEjHTQZwUm6I5w4ZVhpcTaBishmPO4YR78WwBg5IgDp9VHkirJDQyUuJu0ThiacmOQ34i0tlxXl1nA5Z33Fq
# )

# %% [markdown]
# *link do mapa mental:* https://coggle.it/diagram/ZbgPZD9EPefAHtHX/t/-

# %% [markdown]
# # Modelo **(SEIQR)** 🦠

# %% [markdown]
# O modelo SIR foi proposto em 1927 por W.O. Kermack em conjunto com A.G. McKendrick, nesse modelo é considerada a existência de uma população fixa em que cada individuo pode ser classificado em apenas uma das. 3 classes: S (sensível), I (infectado) ou R (removido), em que S são os indivíduos suscetíveis a contrair a doença, I os que possuem a doença e são capazes de transmitir e R os que já foram infectados e agora são imunes, ou seja, não podem ser infectados novamente ou infectar outros.

# %% [markdown]
# Nessa pesquisa, a base é o modelo SIR, porém serão adicionadas mais duas classes: E (exposto) e Q (quarentenado), em que E são os indivíduos infectados mas que não são capazes de transmitir e Q os indivíduos que testaram positivo para a doença e se mantiveram em quarentena. Formando assim o modelo SEIQR.

# %% [markdown]
# O modelo SEIQR é composto por cinco equações ordinarias diferenciais (EDOs) que representam o número de pessoas em cada classe em determinado momento:

# %% [markdown]
# $\dfrac{dS}{dt} = Λ - μS - βS\dfrac{I}{S+E+I+R}$

# %% [markdown]
# $\dfrac{dE}{dt} = βS\dfrac{I}{S+E+I+R} - (μ + ε + ηλ)E $

# %% [markdown]
# $\dfrac{dI}{dt} = εE - (μ+$γ$+α+ηλ)I$

# %% [markdown]
# $\dfrac{dQ}{dt} =ηλ(E +I)-(μ+γ +α)Q$

# %% [markdown]
# $\dfrac{dR}{dt} =  γ(Q + I)- μR$

# %% [markdown]
# Onde:

# %% [markdown]
# Λ : Taxa de nascimento por unidade de tempo\
# μ : Taxa de mortalidade por pessoa por unidade de tempo\
# $α$ : Taxa de fatalidade do COVID-19\
# $β$ : Probabilidade de transmissão da doença por tempo de contato e por número de contato por unidade de tempo\
# ε : Taxa de progressão da exposição da infecção por periodo de tempo\
# $γ$ : Taxa de recuperação de indivíduos infectados do período infeccioso\
# η : Sensibilidade ao teste rápido\
# λ : Porcentagem da população que realizou o teste rápido

# %% [markdown]
# Iremos considerar que pessoas sensíveis possuem a probabilidade de encontrar alguém que pode transmitir a doença de:  \
# \
# $ \dfrac{I}{S + E + I + R}$

# %% [markdown]
# Além disso podemos observar que o número de pessoas que passam de sesíveis para expostas por unidade de tempo é representado como : \
# \
# $ β\dfrac{I}{S + E + I + R}S$

# %% [markdown]
# Também vemos que a taxa em que uma pessoa exposta (E) se torna quarentenada (Q) é representada como: \
# \
# $ ηλE$

# %% [markdown]
# Nós também assumiremos que N é o número total de pessoas na população, ou seja:\
# \
# $N'(t) = S'(t) + E'(t) + I'(t) + Q'(t) + R'(t) = Λ - μ(S +E +I +Q+R)- α(I +Q) $

# %% [markdown]
# # Visualizando os dados 🔍

# %% [markdown]
# ### Importando as bibliotecas necessárias

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %% [markdown]
# ### Definindo os parametros e as condições iniciais

# %%
# Initial conditions
S0 = 0.99  
E0 = 0.01
I0 = 0.01  
R0 = 0.00  
Q0 = 0.00
y0 = [S0, E0, I0, R0, Q0]

# Parameters

BR = 0.00005 #Birth rate per unit of time (Λ)
DR = 0.000205 #Death rate per unit of time (μ)
PT = 5 #Probability of disease transmition per unit of time (β)
PR = 0.33 #Progression rate from exposed to infectious (ε)
FR = 0.0336 #Fatality rate of covid19 (α)
RR = 0.2 #Recovery rate (γ)
SE = 0.85 #Sensitity of rapid test (η)
YR = 0.1 #Percentage of people who takes the test (λ)

# Time vector
t = np.linspace(0, 40, 200)

# %% [markdown]
# ### Definindo o modelo e solução das equações

# %%
def SEIR_model(y, t, BR, DR, PT, PR, FR, RR, SE, YR):
    S, E, I, R, Q = y
    a = I/(S+E+I+R)
    k = SE*YR
    b = DR + RR + FR
    dSdt = BR - (DR*S) - (PT*S*a)
    dEdt = PT*S*a - E*(DR + PR + k)
    dIdt = PR*E - I*(b + k)
    dRdt = RR*(Q+I) - DR*R
    dQdt = k*(E+I) - b*Q
    return [dSdt, dEdt, dIdt, dRdt, dQdt]

# %% [markdown]
# ### Resolvendo as  equações

# %%
# Solve the SEIR model equations
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, SE, YR))

# Extract results
S, E, I, R, Q = solution.T

# %% [markdown]
# # Imprimindo resultados 📈

# %% [markdown]
# Seguindo a variação de uma constante k = SE*YR
# (sensibilidade ao teste rápido * porcentagem de pessoas que realizaram o teste)

# %% [markdown]
# Com isso conseguimos observar a variação de pessoas infectadas, em quarentena, suscetíveis à doença, expostas e removidas, de acordo com o aumento do número de testes rápidos feitos em uma população e o aumento da sua eficiencia.

# %% [markdown]
# ### População infectada

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(t, I, label='k = 0.01')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.1, 1))
S, E, I, R, Q = solution.T
plt.plot(t, I, label='k = 0.10')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.2, 1))
S, E, I, R, Q = solution.T
plt.plot(t, I, label='k = 0.20')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.5, 1))
S, E, I, R, Q = solution.T
plt.plot(t, I, label='k = 0.50')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 1, 1))
S, E, I, R, Q = solution.T
plt.plot(t, I, label='k = 1')
plt.xlabel('Time (days)')
plt.ylabel('Proportion of Population')
plt.title('SEIQR Model Simulation of Infected Population')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pessoas em quarentena

# %%
plt.figure(figsize=(10, 6))
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.01, 1))
plt.plot(t, Q, label='k = 0.01')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.1, 1))
S, E, I, R, Q = solution.T
plt.plot(t, Q, label='k = 0.10')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.2, 1))
S, E, I, R, Q = solution.T
plt.plot(t, Q, label='k = 0.20')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.5, 1))
S, E, I, R, Q = solution.T
plt.plot(t, Q, label='k = 0.50')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 1, 1))
S, E, I, R, Q = solution.T
plt.plot(t, Q, label='k = 1')
plt.xlabel('Time (days)')
plt.ylabel('Proportion of Population')
plt.title('SEIQR Model Simulation of Quarantined Population')
plt.legend()
plt.grid(True)

# %% [markdown]
# ### Pessoas expostas

# %%
plt.figure(figsize=(10, 6))
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.01, 1))
plt.plot(t, E, label='k = 0.01')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.1, 1))
S, E, I, R, Q = solution.T
plt.plot(t, E, label='k = 0.10')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.2, 1))
S, E, I, R, Q = solution.T
plt.plot(t, E, label='k = 0.20')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.5, 1))
S, E, I, R, Q = solution.T
plt.plot(t, E, label='k = 0.50')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 1, 1))
S, E, I, R, Q = solution.T
plt.plot(t, E, label='k = 1')
plt.xlabel('Time (days)')
plt.ylabel('Proportion of Population')
plt.title('SEIQR Model Simulation of Exposed Population')
plt.legend()
plt.grid(True)

# %% [markdown]
# ### Pessoas suscetíveis

# %%
plt.figure(figsize=(10, 6))
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.01, 1))
plt.plot(t, S, label='k = 0.01')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.1, 1))
S, E, I, R, Q = solution.T
plt.plot(t, S, label='k = 0.10')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.2, 1))
S, E, I, R, Q = solution.T
plt.plot(t, S, label='k = 0.20')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.5, 1))
S, E, I, R, Q = solution.T
plt.plot(t, S, label='k = 0.50')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 1, 1))
S, E, I, R, Q = solution.T
plt.plot(t, S, label='k = 1')
plt.xlabel('Time (days)')
plt.ylabel('Proportion of Population')
plt.title('SEIQR Model Simulation of Suscetible Population')
plt.legend()
plt.grid(True)

# %% [markdown]
# ### Pessoas removidas

# %%
plt.figure(figsize=(10, 6))
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.01, 1))
plt.plot(t, R, label='k = 0.01')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.1, 1))
S, E, I, R, Q = solution.T
plt.plot(t, R, label='k = 0.10')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.2, 1))
S, E, I, R, Q = solution.T
plt.plot(t, R, label='k = 0.20')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 0.5, 1))
S, E, I, R, Q = solution.T
plt.plot(t, R, label='k = 0.50')
solution = odeint(SEIR_model, y0, t, args=(BR, DR, PT, PR, FR, RR, 1, 1))
S, E, I, R, Q = solution.T
plt.plot(t, R, label='k = 1')
plt.xlabel('Time (days)')
plt.ylabel('Proportion of Population')
plt.title('SEIQR Model Simulation of Removed Population')
plt.legend()
plt.grid(True)

# %% [markdown]
# ### Resultados 📝

# %% [markdown]
# Por meio dos dados obtidos, sabemos que os fatores η (sensibilidade das pessoas ao teste) e λ (porcentagem populacional que realizou o teste rápido) afetam linearmente o números de pessoas em quarentena (Q). Assim, é possível definir к=ηλ. Também é importante ressaltar que, uma vez que η e λ são valores unitários, o valor representado por к também será. Na pesquisa iremos considerar os valores 0.01, 0.1, 0.2, 0.5, 1.0 para к com o escopo de identificarmos como esse valor influencia na dinâmica de transmissão de COVID-19. Com esses valores, simulamos a dinâmica por meio da resolução das EDOs.
#
# Nos gráficos apresentados, é evidente que a proporção de pessoas infectadas permanece baixa (próxima de zero) quando 100% da população realiza o teste rápido. Além disso, o número de pessoas suscetíveis ao vírus é consideravelmente reduzido nesse cenário, refletindo a eficácia dos testes rápidos na prevenção da propagação da doença em uma população ainda não imunizada por vacinação.
#
# Por outro lado, o aumento do número de testes rápidos realizados resulta em uma diminuição significativa no número de pessoas expostas e removidas (recuperadas ou falecidas) ao longo do período de simulação. Isso sugere não apenas uma redução nas taxas de mortalidade, mas também uma menor exposição da população à doença, indicando um impacto positivo na saúde pública e na capacidade de resposta aos surtos de COVID-19.
#
# Dessa maneira, observa-se claramente o grande impacto que a realização do teste rápido pela população tem na quantidade de pessoas infectadas em um intervalo de 40 dias (como é representado graficamente), reduzindo efetivamente o número de casos e ajudando a controlar a disseminação do vírus. Assim contribuindo de maneira significativa a mitigar a pandemia e destacando a necessidade contínua de investimento e implementação de programas de testagem em larga escala.

# %% [markdown]
# ### Conclusão 📕

# %% [markdown]
# Dessa maneira, podemos concluir que o Modelo SEIQR evidencia a importância que os testes rápidos apresentam no controle da pandemia da COVID-19. Eles possuem o potencial de achatar o pico de contaminação, bem como de reduzir a duração da pandemia e o número de pessoas contaminadas. Além disso, cabe destacar que muitos países não tiveram condições de alavancar uma campanha forte de vacinação pelo seu alto custo e dificuldade de realização. Nesse sentido, os testes rápidos, por serem mais baratos e mais fáceis de serem utilizados (por poderem ser feitos em casa e sem ajuda de um profissional de saúde), podem ser uma opção de fundamental significância na contenção do vírus Sars-Cov-2.

# %% [markdown]
# ### Referências 📗

# %% [markdown]
# https://www.siam.org/Portals/0/Publications/SIURO/Vol15/S146039RR.pdf?ver=2022-10-04-102909-387
# https://rce.casadasciencias.org/rceapp/art/2017/020/
# https://www.medwave.cl/revisiones/revisiontemas/2552.html?lang=en
# https://revistapesquisa.fapesp.br/modelagem-epidemiologica-ganha-visibilidade/
# https://sites.me.ucsb.edu/~moehlis/APC514/tutorials/tutorial_seasonal/node4.html
# https://docs.idmod.org/projects/emod-hiv/en/latest/model-seir.html
# https://www.frontiersin.org/articles/10.3389/fpubh.2020.00230/full
# https://www.aimspress.com/fileOther/PDF/MBE/1551-0018_2014_4_761.pdf
# https://www.youtube.com/watch?v=Lcx2a1jXISc
# https://jckantor.github.io/CBE30338/03.09-COVID-19.html
# https://medium.com/@cd_24/a-simulation-of-the-spread-of-the-pandemic-seir-model-1728fbc9bc4c
# https://www.gov.br/saude/pt-br/assuntos/noticias/2022/dezembro/ministerio-da-saude-distribuiu-mais-de-102-milhoes-de-testes-de-covid-19#:~:text=Segundo%20dados%20da%20Secretaria%20de,pelo%20Plano%20Nacional%20de%20Testagem.
# https://www.rbac.org.br/artigos/analise-comparativa-dos-parametros-de-testes-rapidos-para-o-diagnostico-de-anticorpos-sars-cov-2/
# https://www.gov.br/saude/pt-br/assuntos/coronavirus
